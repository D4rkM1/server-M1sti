# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2d2gpZA3XAGz0gVwysj4wapuuwi_5CowRGzXWNHPnrm2aWoRK" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json		  forge.jar.log		       ops.json
# banned-players.json	  help.yml		       permissions.yml
# bukkit.yml		  journeymap		       plugins
# colabconfig.json	  libraries		       server.properties
# commands.yml		  logs			       spigot.yml
# config			  minecraft_server.1.16.5.jar  usercache.json
# defaultconfigs		  mods			       usernamecache.json
# eula.txt		  mohist-config		       whitelist.json
# forge-1.16.5-36.2.41.jar  mohist.jar		       world
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 2.tcp.ngrok.io:13522
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#
#  __    __   ______   __  __   __   ______   ______
# /\ "-./  \ /\  __ \ /\ \_\ \ /\ \ /\  ___\ /\__  _\
# \ \ \-./\ \\ \ \/\ \\ \  __ \\ \ \\ \___  \\/_/\ \/
#  \ \_\ \ \_\\ \_____\\ \_\ \_\\ \_\\/\_____\  \ \_\
#   \/_/  \/_/ \/_____/ \/_/\/_/ \/_/ \/_____/   \/_/
#
#
#                                       Welcome to Mohist 1.16.5 ! - Mohist Developement Group - 1.16.5-1220, Java 65.0
# Checking libraries, please wait...
# DownloadSource: MOHIST
# All libraries are nice :) !
# Checking the installation, please wait.
# Finished the install verification process !
# [06:50:58 INFO]: Update in check...
# [06:50:58 INFO]: If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# [06:50:58 INFO]: No update found, latest version: (1.16.5-1220) current version: (1.16.5-1220)
# [06:50:58 INFO]: ModLauncher running: args [--gameDir, ., --launchTarget, fmlserver, --fml.mohistVersion, 1220, --fml.forgeVersion, 36.2.41, --fml.mcpVersion, 20210115.111550, --fml.mcVersion, 1.16.5, --fml.forgeGroup, com.mohistmc, nogui]
# [06:50:58 INFO]: ModLauncher mohist-8.1.3 starting: java version 21.0.2 by Microsoft
# [06:50:58 INFO]: Added Lets Encrypt root certificates as additional trust
# [06:50:58 INFO]: SpongePowered MIXIN Subsystem Version=0.8.4 Source=file:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.4/mixin-0.8.4.jar Service=ModLauncher Env=SERVER
# [06:51:00 ERROR]: Mixin config boss_tools.mixin.json does not specify "minVersion" property
# [06:51:00 INFO]: Launching target 'fmlserver' with arguments [--gameDir, ., nogui]
# [backpacked-transformer.js] Patching PlayerEntity#<init>
# [backpacked-transformer.js] Successfully patched PlayerEntity#<init>
# [backpacked-transformer.js] Patching ServerPlayerNetHandler#func_147344_a
# [backpacked-transformer.js] Successfully patched ServerPlayerNetHandler#func_147344_a
# [backpacked-transformer.js] Patching PlayerEntity#<init>
# [backpacked-transformer.js] Successfully patched PlayerEntity#<init>
# [06:51:07 WARN]: @Final field field_76203_h:Ljava/util/Map; in supplementaries.mixins.json:MapMixin should be final
# [06:51:10 INFO]: Potentially Dangerous alternative prefix `citadel` for name `debug`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:10 INFO]: Potentially Dangerous alternative prefix `citadel` for name `citadel_book`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:10 INFO]: Potentially Dangerous alternative prefix `walljump` for name `walljump`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:10 INFO]: Potentially Dangerous alternative prefix `walljump` for name `doublejump`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:10 INFO]: Potentially Dangerous alternative prefix `walljump` for name `speedboost`, expected `minecraft`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:11 INFO]: Infernal Expansion: Blocks Registered!
# [06:51:11 INFO]: Infernal Expansion: Items Registered!
# [06:51:11 INFO]: Infernal Expansion: Entity Types Registered!
# [06:51:11 INFO]: Infernal Expansion: Painting Types Registered!
# [06:51:11 INFO]: Infernal Expansion: Tile Entity Types Registered!
# [06:51:11 WARN]: Falling Leaves is a client only mod and should be removed from the mods list
# [06:51:11 INFO]: Here we go! Launching Dungeon Crawl 2.2.4...
# [06:51:11 INFO]: net.minecraft.world.gen.feature.StructureFeature@5743dabe
# [06:51:11 INFO]: dungeoncrawl:dungeon
# [06:51:11 INFO]: Registered the class com.tiviacz.travelersbackpack.fluids.effects.WaterEffect as a FluidEffect for Water with the ID 0
# [06:51:11 INFO]: Registered the class com.tiviacz.travelersbackpack.fluids.effects.LavaEffect as a FluidEffect for Lava with the ID 1
# [06:51:12 INFO]: Potentially Dangerous alternative prefix `froggychair` for name `seat`, expected `ironagefurniture`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:12 INFO]: Forge mod loading, version 36.2.41, for MC 1.16.5 with MCP 20210115.111550
# [06:51:12 INFO]: MinecraftForge v36.2.41 Initialized
# [06:51:12 INFO]: EventDispatcherRegistry initialized
# [06:51:13 INFO]: Vanilla is real good, but chocolate is better, let's be honest. :)
# [06:51:13 INFO]: Skipped compatibility for mod immersiveengineering.
# [06:51:13 INFO]: Constructing Mod: Spartan Shields
# [06:51:13 INFO]: IceAndFire is loaded -> Adjusting default fire related configuration.
# [06:51:14 ERROR]: You are loading Back Tools on a server. Back Tools is a client only mod!
# [06:51:32 INFO]: Registering Items
# [06:51:32 INFO]: Registered Items successfully!
# [06:51:32 INFO]: Items registered.
# [06:51:32 INFO]: Registering Enchantments
# [06:51:32 INFO]: Registered Enchantments successfully!
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:grizzly_bear, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:roadrunner, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:bone_serpent, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:bone_serpent_part, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:gazelle, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:crocodile, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:fly, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:hummingbird, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:orca, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:sunbird, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:gorilla, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:crimson_mosquito, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:rattlesnake, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:endergrade, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:hammerhead_shark, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:lobster, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:komodo_dragon, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:capuchin_monkey, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:centipede_head, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:centipede_body, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:centipede_tail, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:warped_toad, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:moose, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:mimicube, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:raccoon, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:blobfish, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:seal, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:cockroach, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:shoebill, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:elephant, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:soul_vulture, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:snow_leopard, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:spectre, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:crow, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:alligator_snapping_turtle, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:mungus, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:mantis_shrimp, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:guster, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:warped_mosco, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:straddler, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:stradpole, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:emu, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:platypus, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:dropbear, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:tasmanian_devil, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for alexsmobs:kangaroo, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: Called deprecated GlobalEntityTypeAttributes#put for supplementaries:firefly, use EntityAttributeCreationEvent instead.
# [06:51:33 WARN]: -------Please ignore the following error!------
# [06:51:33 INFO]: Potentially Dangerous alternative prefix `minecraft` for name `night_vision`, expected `vampirism`. This could be a intended override, but in most cases indicates a broken mod.
# [06:51:33 WARN]: -----------------------------------------------
# [06:51:34 WARN]: Registry minecraft:worldgen/biome: The object minecraft:the_end has been registered twice for the same name minecraft:the_end.
# [06:51:34 WARN]: Registry minecraft:worldgen/biome: The object minecraft:end_barrens has been registered twice for the same name minecraft:end_barrens.
# [06:51:34 WARN]: Registry minecraft:worldgen/biome: The object minecraft:small_end_islands has been registered twice for the same name minecraft:small_end_islands.
# [06:51:34 WARN]: Registry minecraft:worldgen/biome: The object minecraft:end_midlands has been registered twice for the same name minecraft:end_midlands.
# [06:51:34 WARN]: Registry minecraft:worldgen/biome: The object minecraft:end_highlands has been registered twice for the same name minecraft:end_highlands.
# [06:51:36 INFO]: Loading config spartanshields-common.toml
# [06:51:36 INFO]: Loading config spartanshields-common.toml
# [06:51:36 INFO]: Loading config spartanshields-common.toml
# [06:51:36 INFO]: RingOfRepair common setup
# [06:51:36 INFO]: Common Setup
# [06:51:36 INFO]: Registering Structure Piece Types
# [06:51:36 INFO]: Setting up Spartan Shields!
# [06:51:36 INFO]: Loading Module Chain Linkage
# [06:51:36 INFO]: Loading Module Chains Connect Blocks
# [06:51:36 INFO]: Loading Module Chute
# [06:51:36 INFO]: Loading Module Color Slime
# [06:51:36 INFO]: Loading Module Dispensers Place Blocks
# [06:51:36 INFO]: Loading Module Ender Watcher
# [06:51:36 INFO]: Loading Module Endermites Form Shulkers
# [06:51:36 INFO]: Loading Module Feeding Trough
# [06:51:36 INFO]: Loading Module Gravisand
# [06:51:36 INFO]: Loading Module Iron Rod
# [06:51:36 INFO]: Loading Module Metal Buttons
# [06:51:36 INFO]: Loading Module Obsidian Plate
# [06:51:36 INFO]: Loading Module Pistons Move Tile Entities
# [06:51:36 INFO]: Loading Module Redstone Circuit
# [06:51:36 INFO]: Loading Module Weather Sensor
# [06:51:36 INFO]: Loading Module Bamboo Mat
# [06:51:36 INFO]: Loading Module Burn Vines
# [06:51:36 INFO]: Loading Module Cobblestone Bricks
# [06:51:36 INFO]: Loading Module Compressed Blocks
# [06:51:36 INFO]: Loading Module Duskbound Blocks
# [06:51:36 INFO]: Loading Module Framed Glass
# [06:51:36 INFO]: Loading Module Gold Bars
# [06:51:36 INFO]: Loading Module Grate
# [06:51:36 INFO]: Loading Module Hedges
# [06:51:36 INFO]: setup method executed
# [06:51:36 INFO]: Loading Module Iron Plates
# [06:51:36 INFO]: Loading Module Item Frames
# [06:51:36 INFO]: Loading Module Leaf Carpet
# [06:51:36 INFO]: Loading Module Lit Lamp
# [06:51:36 INFO]: Loading Module Midori
# [06:51:36 INFO]: Loading Module More Brick Types
# [06:51:36 INFO]: Loading Module More Potted Plants
# [06:51:36 INFO]: Loading Module More Stone Variants
# [06:51:36 INFO]: Loading Module Nether Brick Fence Gate
# [06:51:36 INFO]: Loading Module Paper Decor
# [06:51:36 INFO]: Loading Module Quilted Wool
# [06:51:36 INFO]: Loading Module Rope
# [06:51:36 INFO]: Loading Module Shallow Dirt
# [06:51:36 INFO]: Loading Module Shingles
# [06:51:36 INFO]: Loading Module Soul Sandstone
# [06:51:36 INFO]: Loading Module Stained Planks
# [06:51:36 INFO]: Loading Module Stools
# [06:51:36 INFO]: Loading Module Sturdy Stone
# [06:51:36 INFO]: Loading Module Tallow And Candles
# [06:51:36 INFO]: Loading Module Thatch
# [06:51:36 INFO]: Loading Module Tie Leads To Fences
# [06:51:36 INFO]: Loading Module Turf
# [06:51:36 INFO]: Loading Module Variant Bookshelves
# [06:51:36 INFO]: Loading Module Variant Chests
# [06:51:36 INFO]: Loading Module Variant Ladders
# [06:51:36 INFO]: Loading Module Vertical Planks
# [06:51:36 INFO]: Loading Module Vertical Slabs
# [06:51:36 INFO]: Loading Module Wooden Posts
# [06:51:36 INFO]: Loading Module Chests In Boats
# [06:51:36 INFO]: Loading Module Easy Transfering
# [06:51:36 INFO]: Loading Module Hotbar Changer
# [06:51:36 INFO]: Loading Module Inventory Sorting
# [06:51:36 INFO]: Loading Module Item Sharing
# [06:51:36 INFO]: Loading Module Right Click Armor
# [06:51:36 INFO]: Loading Module Shulker Box Right Click
# [06:51:36 INFO]: Loading Module Ancient Tomes
# [06:51:36 INFO]: Loading Module Bottled Cloud
# [06:51:36 INFO]: Loading Module Camera
# [06:51:36 INFO]: Loading Module Color Runes
# [06:51:36 INFO]: Loading Module Pathfinder Maps
# [06:51:36 INFO]: Loading Module Pickarang
# [06:51:36 INFO]: Loading Module Seed Pouch
# [06:51:36 INFO]: Loading Module Slime In A Bucket
# [06:51:36 INFO]: Loading Module Trowel
# [06:51:36 INFO]: Loading Module Skull Pikes
# [06:51:36 INFO]: Loading Module Armed Armor Stands
# [06:51:36 INFO]: Loading Module Automatic Recipe Unlock
# [06:51:36 INFO]: Loading Module Axe Leaf Harvesting
# [06:51:36 INFO]: Loading Module Campfires Boost Elytra
# [06:51:36 INFO]: Loading Module Compasses Work Everywhere
# [06:51:36 INFO]: Loading Module Dirt To Path
# [06:51:36 INFO]: Loading Module Double Door Opening
# [06:51:36 INFO]: Loading Module Dragon Scales
# [06:51:36 INFO]: Loading Module Emotes
# [06:51:36 INFO]: Loading Module Enhanced Ladders
# [06:51:36 INFO]: Loading Module Glass Shard
# [06:51:36 INFO]: Loading Module Hoe Harvesting
# [06:51:36 INFO]: Loading Module Improved Sleeping
# [06:51:36 INFO]: Loading Module Infinity Bucket
# [06:51:36 INFO]: Loading Module Lava Bucket As Trash
# [06:51:36 INFO]: Loading Module Lock Rotation
# [06:51:36 INFO]: Loading Module Note Block Mob Sounds
# [06:51:36 INFO]: Loading Module Pat The Dogs
# [06:51:36 INFO]: Loading Module Poison Potato Usage
# [06:51:36 INFO]: Loading Module Reacharound Placing
# [06:51:36 INFO]: Loading Module Replace Scaffolding
# [06:51:36 INFO]: Loading Module Sign Editing
# [06:51:36 INFO]: Loading Module Simple Harvest
# [06:51:36 INFO]: Loading Module Snow Golem Player Heads
# [06:51:36 INFO]: Loading Module Springy Slime
# [06:51:36 INFO]: Loading Module Utility Recipes
# [06:51:36 INFO]: Loading Module Villagers Follow Emeralds
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:advanced_hunter, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Big Dungeon
# [06:51:36 INFO]: Loading Module Big Stone Clusters
# [06:51:36 INFO]: Loading Module Biotite
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:advanced_hunter_imob, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Blossom Trees
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:advanced_vampire, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Cave Roots
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:advanced_vampire_imob, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Chorus Vegetation
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:blinding_bat, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Crevices
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:converted_creature, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Fairy Rings
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:converted_creature_imob, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Mega Caves
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:converted_horse, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Monster Box
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:converted_sheep, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Nether Obsidian Spikes
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:dummy_creature, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module New Stone Types
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:hunter, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Realistic World Gen
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:hunter_imob, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Speleothems
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:hunter_trainer, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Spiral Spires
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:hunter_trainer_dummy, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Underground Clay
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:vampire, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Brimstone Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:vampire_imob, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Cave Crystal Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:vampire_baron, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Elder Prismarine Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:villager_angry, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Glowshroom Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:villager_converted, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Lush Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:hunter_minion, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Overgrown Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:vampire_minion, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Permafrost Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:task_master_hunter, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Sandstone Underground Biome
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for vampirism:task_master_vampire, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Loading Module Slime Underground Biome
# [06:51:36 INFO]: Loading Module Spider Nest Underground Biome
# [06:51:36 INFO]: Loading Module Crabs
# [06:51:36 INFO]: Loading Module Forgotten
# [06:51:36 INFO]: Loading Module Foxhound
# [06:51:36 INFO]: Loading Module Frogs
# [06:51:36 INFO]: Loading Module Stonelings
# [06:51:36 INFO]: Loading Module Toretoise
# [06:51:36 INFO]: Loading Module Wraith
# [06:51:36 INFO]: Loading Module Auto Walk Keybind
# [06:51:36 INFO]: Loading Module Back Button Keybind
# [06:51:36 INFO]: Loading Module Chest Searching
# [06:51:36 INFO]: Loading Module Greener Grass
# [06:51:36 INFO]: Loading Module Improved Mount Hud
# [06:51:36 INFO]: Loading Module Improved Tooltips
# [06:51:36 INFO]: Loading Module Usage Ticker
# [06:51:36 INFO]: Loading Module Variant Animal Textures
# [06:51:36 INFO]: Loading Module Backpack
# [06:51:36 INFO]: Loading Module Magnets
# [06:51:36 INFO]: Loading Module Matrix Enchanting
# [06:51:36 INFO]: Loading Module Pipes
# [06:51:36 INFO]: Loading Module Totem Of Holding
# [06:51:36 INFO]: Loading Module Adjustable Chat
# [06:51:36 INFO]: Loading Module Custom Underground Biome
# [06:51:36 INFO]: Loading Module Game Nerfs
# [06:51:36 INFO]: Loading Module Narrator Readout
# [06:51:36 INFO]: Loading Module Overlay Shader
# [06:51:36 INFO]: Fixing vanilla night vision potion types
# [06:51:36 INFO]: Starting version check at https://maxanier.de/projects/vampirism/versions.json
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:stoneling, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:leash_knot_fake, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:forgotten, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:frog, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:foxhound, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:wrapped, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:toretoise, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:wraith, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for quark:crab, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:alien, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:pygro, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:mogler, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:alien_zombie, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:star_crawler, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:rocket_t1, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:rocket_t2, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:rocket_t3, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:lander, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for boss_tools:rover, use EntityAttributeCreationEvent instead.
# [06:51:36 INFO]: Initializing Packet Registries
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for betterendforge:end_fish, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for betterendforge:dragonfly, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for betterendforge:shadow_walker, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for betterendforge:end_slime, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for betterendforge:cubozoa, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for betterendforge:silk_moth, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:soulwizard, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:weathervanespin, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:greenbanner, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:gategold, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:gategoldopen, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:windpipes, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:windpipesrotation_1, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:windpipesrotation_2, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:electric, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:slash, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:slash_2, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:slash_3, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:slash_4, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:slash_5, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:archillager, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:namelessno_active, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:necromancer_active, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:wraith, use EntityAttributeCreationEvent instead.
# [06:51:36 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:skeleton_vangruard, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dragon_egg, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dragon_skull, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:fire_dragon, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:ice_dragon, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:lightning_dragon, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:hippogryph, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:gorgon, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:stone_statue, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:pixie, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:cyclops, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:siren, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:hippocampus, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:deathworm, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:cockatrice, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:stymphalian_bird, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:troll, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_worker, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_soldier, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_sentinel, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_royal, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_queen, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_egg, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:myrmex_swarmer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:amphithere, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:sea_serpent, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:mob_skull, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_thrall, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_lich, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_beast, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_horse, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_ghoul, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_knight, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:dread_scuttler, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:hydra, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for iceandfire:ghost, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstone_monstrosity, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:pigchest, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:babykeysleep, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:babykeybluesleep, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:babykeygold, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illagergeomancerbomb, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illagergeomancer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:frozenzombie, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:babykeyblue, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:jackolantern, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:little_grebe, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:cindershell, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:lizard, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:lilytad, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:friendly_sporeling, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:hostile_sporeling, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:neutral_sporeling, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for cnb:yeti, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for savageandravage:creepie, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for savageandravage:griefer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for savageandravage:skeleton_villager, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for savageandravage:iceologer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for savageandravage:executioner, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonecube, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mossyskeleton, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:junglezombie, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonegolem, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:vindicatorvariant, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:vindicatorroyale, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:vindicatorroyaleblue, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:chef, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:nameless, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:necromancer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:traderlamaloot, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:enchanterillager, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:monstrositysleep, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:cauldron_boss, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:cauldronbosssit, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:magicalzoombie, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:magical_vindicxator, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illagerjasper, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illusionistjasperattack, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:quickgrowingvine, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:poisonquillvine, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mushroommonstrosity, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mushroommonstersleep, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:wishperer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonemoshroom, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:archillager_friend, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:cauldronslimes, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mobspawner, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:leaper, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:wickedwraith, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:chillager, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:chillagerattack, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:geomancerbombactive, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonemonteruty_active, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:ender_avatar, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:shootsender, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:archconvert, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:jungle_abomination, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstone_coredisabled, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstone_core, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:jungle_abomination_death, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:jungle_abomination_noactive, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:zombievangruard, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:pillagerarmorer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:crownwraith, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:wraithwretchednoactive, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:wraithwretcheddeath, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonegolemsit, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonegolemdeath, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:caldrondead, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:namelessdeath, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:necromancer_bos_sdeath, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:blue_pillagerarmorer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:redstonemine, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illusionerbowclone, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illusionerbowclone_2, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:illusionerbowclone_3, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:icecreeper, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:windcaller, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:windcallerattack, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:woolycow, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mountaineer, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mountaineer_captain, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mountaineeriron, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:squallgolemnoactive, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:mistralgolemnoactive, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:magicalzombie, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:magicalhusk, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:sheepred, use EntityAttributeCreationEvent instead.
# [06:51:37 WARN]: Called deprecated GlobalEntityTypeAttributes#put for duneons:sheepgreen, use EntityAttributeCreationEvent instead.
# ...
# [06:53:17 INFO]: Crazy Enchantment Hooks
# [06:53:17 INFO]: VAULT: Enabled
# [06:53:17 WARN]: [NBTAPI] The NBT-API located at 'package me.badbones69.crazyenchantments.plugin.lib.de.tr7zw.changeme.nbtapi' seems to be outdated!
# [06:53:17 WARN]: [NBTAPI] Current Version: '2.11.1' Newest Version: 2.12.2'
# [06:53:17 WARN]: [NBTAPI] Please update the NBTAPI or the plugin that contains the api(nag the mod author when the newest release has an old version, not the NBTAPI dev)!
# [06:53:18 INFO]: [NametagEdit] Enabling NametagEdit v4.5.23
# [06:53:18 INFO]: [NametagEdit] Successfully loaded using bukkit version: v1_16_R3
# [06:53:18 INFO]: [NametagEdit] Found LuckPerms! Hooking in.
# [06:53:18 INFO]: [Essentials] Enabling Essentials v2.21.0-dev+67-622c814
# [06:53:19 ERROR]: You are running a server that does not properly support Bukkit plugins. Bukkit plugins should not be used with Forge/Fabric mods! For Forge: Consider using ForgeEssentials, or SpongeForge + Nucleus.
# [06:53:19 INFO]: Status determining class: brand:Mohist
# [06:53:19 INFO]: Attempting to convert old kits in config.yml to new kits.yml
# [06:53:19 INFO]: No kits found to migrate.
# [06:53:19 INFO]: Loaded 39095 items from items.json.
# [06:53:19 INFO]: Using locale en
# [06:53:19 INFO]: ServerListPingEvent: Spigot iterator API
# [06:53:19 INFO]: Starting Metrics. Opt-out using the global bStats config.
# [06:53:19 INFO]: [Vault] [Economy] Essentials Economy hooked.
# [06:53:20 INFO]: Using Vault based permissions (LuckPerms)
# [06:53:20 INFO]: [UltimateChat] Enabling UltimateChat v1.9.1
# [06:53:20 INFO]: [UltimateChat] All configurations loaded!
# [06:53:20 INFO]: [UltimateChat] Language file loaded - Using: EN-US
# [06:53:20 INFO]: [PlaceholderAPI] Successfully registered internal expansion: uchat [1.9.1]
# [06:53:20 INFO]: [UltimateChat] PlaceHolderAPI found. Hooked and registered some chat placeholders with relational tag feature.
# [06:53:20 INFO]: [UltimateChat] Vault economy found. Hooked.
# [06:53:20 INFO]: [UltimateChat] Vault chat found. Hooked.
# [06:53:20 INFO]: [UltimateChat] Vault perms found. Hooked.
# [06:53:20 INFO]: [UltimateChat] Init API module...
# [06:53:20 INFO]: [UltimateChat] Server Version: 1.16.5-R0.1-SNAPSHOT
# [06:53:20 INFO]:
# [06:53:20 INFO]:   _    _ _ _   _                 _        _____ _           _
# [06:53:20 INFO]:  | |  | | | | (_)               | |      / ____| |         | |
# [06:53:20 INFO]:  | |  | | | |_ _ _ __ ___   __ _| |_ ___| |    | |__   __ _| |_
# [06:53:20 INFO]:  | |  | | | __| | '_ ` _ \ / _` | __/ _ \ |    | '_ \ / _` | __|
# [06:53:20 INFO]:  | |__| | | |_| | | | | | | (_| | ||  __/ |____| | | | (_| | |_
# [06:53:20 INFO]:   \____/|_|\__|_|_| |_| |_|\__,_|\__\___|\_____|_| |_|\__,_|\__|
# [06:53:20 INFO]:
# [06:53:20 INFO]: UltimateChat v1.9.1 enabled!
# [06:53:20 INFO]:
# [06:53:20 INFO]: [UltimateChat] Metrics enabled! See our stats here: https://bstats.org/plugin/bukkit/UltimateChat
# [06:53:20 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [06:53:20 INFO]: [PlaceholderAPI] Placeholder expansion registration initializing...
# [06:53:20 INFO]: Done (69.785s)! For help, type "help"
# [06:53:20 INFO]: RingOfRepair server setup
# [06:53:20 INFO]: {SPAWN_DRAGON_SKELETON_I_CF=true, HYDRA_CAVE_CF=true, SPAWN_SEA_SERPENT_CF=true, SPAWN_STYMPHALIAN_BIRD_CF=true, SPAWN_WANDERING_CYCLOPS_CF=true, PIXIE_VILLAGE_CF=false, SPAWN_DEATH_WORM_CF=true, FIRE_DRAGON_CAVE_CF=true, SIREN_ISLAND_CF=true, MYRMEX_HIVE_DESERT_CF=true, SPAWN_HIPPOCAMPUS_CF=true, FIRE_DRAGON_ROOST_CF=true, MYRMEX_HIVE_JUNGLE_CF=true, GORGON_TEMPLE_CF=true, COPPER_ORE_CF=true, SILVER_ORE_CF=true, LIGHTNING_DRAGON_CAVE_CF=true, SPAWN_DRAGON_SKELETON_F_CF=true, AMETHYST_ORE_CF=true, SPAWN_DRAGON_SKELETON_L_CF=true, LIGHTNING_LILY_CF=true, MAUSOLEUM_CF=true, ICE_DRAGON_CAVE_CF=true, GRAVEYARD_CF=true, SAPPHIRE_ORE_CF=true, LIGHTNING_DRAGON_ROOST_CF=true, CYCLOPS_CAVE_CF=true, FROST_LILY_CF=true, FIRE_LILY_CF=true, ICE_DRAGON_ROOST_CF=true}
# [06:53:20 INFO]: {TROLL_S=true, HIPPOGRYPH=true, AMPHITHERE=true, COCKATRICE=true, TROLL_M=true, DREAD_LICH=true, TROLL_F=true}
# [06:53:20 INFO]: Essentials found a compatible payment resolution method: Vault Compatibility Layer (v1.7.3-b131)!
# [06:53:20 INFO]: [PlaceholderAPI] Successfully registered external expansion: statistic [2.0.1]
# [06:53:20 INFO]: [Vault] Checking for Updates ...
# [06:53:20 INFO]: [PlaceholderAPI] Successfully registered external expansion: bungee [2.3]
# [06:53:20 INFO]: [PlaceholderAPI] Successfully registered external expansion: player [2.0.8]
# [06:53:20 INFO]: 3 placeholder hook(s) registered!
# [06:53:20 INFO]: [Vault] No new version available
# [06:53:20 INFO]: Fetching version information...
# [06:53:20 WARN]: You're 1 EssentialsX dev build(s) out of date!
# [06:53:20 WARN]: Download it here: https://essentialsx.net/downloads.html
# [06:53:29 INFO]: UUID of player zM1sti is c5b156c5-8e46-3235-9717-4eb8d26a3c70
# [06:53:29 INFO]: Client attempting to join with 78 mods : extraarmor, mowziesmobs, supermartijn642configlib, editenchanting, trashslot, infernalexp, jei, abnormals_core, caelus, obscure_api, colytra, guideapi-vp, boss_tools, neat, bettercaves, waystones, fallingleaves, mcwpaintings, ring_of_repair, journeymap, cookingforblockheads, jumpoverfences, citadel, alexsmobs, travelersbackpack, naturescompass, yungsapi, instrumentus, dungeoncrawl, simpleplanes, mcwdoors, travellersboots, iceandfire, orcz, ironagefurniture, waila, walljump, ichunutil, forge, twilightforest, tlskincape, supplementaries, betterendforge, corpse, dungeons_arise, duneons, chocolate, minecraft, mcwbridges, repurposed_structures, silentlib, biomesoplenty, endrem, syp, scarecrowsterritory, storage_overhaul, cnb, spartanshields, savageandravage, autoreglib, quark, backpacked, backpacker, obfuscate, buildersaddition, theabyss, vampirism, teamlapenlib, propellerhats, backtools, adorn, quickharvest, getinthebucketmod, rpg-hud, bettermineshafts, geckolib3, xpbook, bigbuckets
# [06:53:33 WARN]: java.lang.NoSuchFieldException: modifiers
# [06:53:33 WARN]: 	at java.base/java.lang.Class.getDeclaredField(Class.java:2782)
# [06:53:33 WARN]: 	at com.mrcrayfish.backpacked.Backpacked.getFieldAndSetAccessible(Backpacked.java:227)
# [06:53:33 WARN]: 	at com.mrcrayfish.backpacked.Backpacked.patchInventory(Backpacked.java:199)
# [06:53:33 WARN]: 	at com.mrcrayfish.backpacked.Backpacked.onPlayerInit(Backpacked.java:192)
# [06:53:33 WARN]: 	at net.minecraft.entity.player.PlayerEntity.<init>(PlayerEntity.java:196)
# [06:53:33 WARN]: 	at net.minecraft.entity.player.ServerPlayerEntity.<init>(ServerPlayerEntity.java:213)
# [06:53:33 WARN]: 	at net.minecraft.server.management.PlayerList.func_148545_a(PlayerList.java:511)
# [06:53:33 WARN]: 	at net.minecraft.server.management.PlayerList.canPlayerLogin(PlayerList.java:445)
# [06:53:33 WARN]: 	at net.minecraft.network.login.ServerLoginNetHandler.func_147326_c(ServerLoginNetHandler.java:147)
# [06:53:33 WARN]: 	at net.minecraft.network.login.ServerLoginNetHandler.func_73660_a(ServerLoginNetHandler.java:75)
# [06:53:33 WARN]: 	at net.minecraft.network.NetworkManager.func_74428_b(NetworkManager.java:239)
# [06:53:33 WARN]: 	at net.minecraft.network.NetworkSystem.func_151269_c(NetworkSystem.java:142)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_71190_q(MinecraftServer.java:1121)
# [06:53:33 WARN]: 	at net.minecraft.server.dedicated.DedicatedServer.func_71190_q(DedicatedServer.java:345)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_71217_p(MinecraftServer.java:1033)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_240802_v_(MinecraftServer.java:847)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_240783_a_(MinecraftServer.java:267)
# [06:53:33 WARN]: 	at java.base/java.lang.Thread.run(Thread.java:1583)
# [06:53:33 WARN]: java.lang.NoSuchFieldException: modifiers
# [06:53:33 WARN]: 	at java.base/java.lang.Class.getDeclaredField(Class.java:2782)
# [06:53:33 WARN]: 	at com.mrcrayfish.backpacked.Backpacked.getFieldAndSetAccessible(Backpacked.java:227)
# [06:53:33 WARN]: 	at com.mrcrayfish.backpacked.Backpacked.patchInventory(Backpacked.java:203)
# [06:53:33 WARN]: 	at com.mrcrayfish.backpacked.Backpacked.onPlayerInit(Backpacked.java:192)
# [06:53:33 WARN]: 	at net.minecraft.entity.player.PlayerEntity.<init>(PlayerEntity.java:196)
# [06:53:33 WARN]: 	at net.minecraft.entity.player.ServerPlayerEntity.<init>(ServerPlayerEntity.java:213)
# [06:53:33 WARN]: 	at net.minecraft.server.management.PlayerList.func_148545_a(PlayerList.java:511)
# [06:53:33 WARN]: 	at net.minecraft.server.management.PlayerList.canPlayerLogin(PlayerList.java:445)
# [06:53:33 WARN]: 	at net.minecraft.network.login.ServerLoginNetHandler.func_147326_c(ServerLoginNetHandler.java:147)
# [06:53:33 WARN]: 	at net.minecraft.network.login.ServerLoginNetHandler.func_73660_a(ServerLoginNetHandler.java:75)
# [06:53:33 WARN]: 	at net.minecraft.network.NetworkManager.func_74428_b(NetworkManager.java:239)
# [06:53:33 WARN]: 	at net.minecraft.network.NetworkSystem.func_151269_c(NetworkSystem.java:142)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_71190_q(MinecraftServer.java:1121)
# [06:53:33 WARN]: 	at net.minecraft.server.dedicated.DedicatedServer.func_71190_q(DedicatedServer.java:345)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_71217_p(MinecraftServer.java:1033)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_240802_v_(MinecraftServer.java:847)
# [06:53:33 WARN]: 	at net.minecraft.server.MinecraftServer.func_240783_a_(MinecraftServer.java:267)
# [06:53:33 WARN]: 	at java.base/java.lang.Thread.run(Thread.java:1583)
# [06:53:33 INFO]: zM1sti[/[0:0:0:0:0:0:0:1%0]:53028] logged in with entity id 624 at (-8.411, 87, -3,475.551)
# [06:53:34 INFO]: Syncing config to zM1sti (c5b156c5-8e46-3235-9717-4eb8d26a3c70)
# [06:54:22 INFO]: zM1sti issued server command: /gi
# [06:54:34 INFO]: zM1sti issued server command: /give zM1sti changsign
# [06:55:12 INFO]: zM1sti issued server command: /give zM1sti editchant
# [06:55:22 INFO]: zM1sti issued server command: /give zM1sti editchanting:
# [06:55:36 INFO]: zM1sti issued server command: /give zM1sti editchanting:enchantmen
# [06:55:44 INFO]: zM1sti issued server command: /give zM1sti editchanting:enchantment
# [06:55:55 INFO]: zM1sti issued server command: /give zM1sti editchanting:enchantment_edit_table
# [06:55:57 INFO]: zM1sti issued server command: /give zM1sti editchanting:enchantment_edit_table 1
# [06:56:16 INFO]: zM1sti issued server command: /give zM1sti obsidian
# [06:56:46 INFO]: zM1sti issued server command: /give zM1sti lapis_block 23
# [06:57:01 INFO]: zM1sti issued server command: /give zM1sti
# [06:57:43 INFO]: zM1sti issued server command: /give zM1sti chiseled_quartz_block 10
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:03:55 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:03:56 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:03:57 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:03:57 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:03:57 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:03:58 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:03:58 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:04:03 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:04:04 INFO]: zM1sti issued server command: /xp give zM1sti 1132}
# [07:04:05 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:05:49 INFO]: zM1sti has completed the challenge [You can't break through!]
# [07:06:02 INFO]: zM1sti issued server command: /xp give zM1sti 1132 l
# [07:06:04 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:06 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:07 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:07 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:08 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:08 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:08 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:06:09 INFO]: zM1sti issued server command: /xp give zM1sti 1132
# [07:08:30 INFO]: zM1sti issued server command: /xp give zM1sti 113200
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [07:15:34 INFO]: zM1sti has made the advancement [First Blood]
# [07:16:48 WARN]: net.minecraftforge.fml.common.ObfuscationReflectionHelper$UnableToFindFieldException: java.lang.NoSuchFieldException: field_226571_aq_
# [07:16:48 WARN]: 	at net.minecraftforge.fml.common.ObfuscationReflectionHelper.findField(ObfuscationReflectionHelper.java:228)
# [07:16:48 WARN]: 	at com.github.alexthe666.iceandfire.entity.EntityTideTrident.func_213868_a(EntityTideTrident.java:73)
# [07:16:48 WARN]: 	at net.minecraft.entity.projectile.ProjectileEntity.func_70227_a(ProjectileEntity.java:126)
# [07:16:48 WARN]: 	at net.minecraft.entity.projectile.ProjectileEntity.preOnHit(ProjectileEntity.java:118)
# [07:16:48 WARN]: 	at net.minecraft.entity.projectile.AbstractArrowEntity.func_70071_h_(AbstractArrowEntity.java:196)
# [07:16:48 WARN]: 	at net.minecraft.entity.projectile.TridentEntity.func_70071_h_(TridentEntity.java:90)
# [07:16:48 WARN]: 	at net.minecraft.world.server.ServerWorld.func_217479_a(ServerWorld.java:780)
# [07:16:48 WARN]: 	at net.minecraft.world.World.func_217390_a(World.java:707)
# [07:16:48 WARN]: 	at net.minecraft.world.server.ServerWorld.func_72835_b(ServerWorld.java:524)
# [07:16:48 WARN]: 	at net.minecraft.server.MinecraftServer.func_71190_q(MinecraftServer.java:1100)
# [07:16:48 WARN]: 	at net.minecraft.server.dedicated.DedicatedServer.func_71190_q(DedicatedServer.java:345)
# [07:16:48 WARN]: 	at net.minecraft.server.MinecraftServer.func_71217_p(MinecraftServer.java:1033)
# [07:16:48 WARN]: 	at net.minecraft.server.MinecraftServer.func_240802_v_(MinecraftServer.java:847)
# [07:16:48 WARN]: 	at net.minecraft.server.MinecraftServer.func_240783_a_(MinecraftServer.java:267)
# [07:16:48 WARN]: 	at java.base/java.lang.Thread.run(Thread.java:1583)
# [07:16:48 WARN]: Caused by: java.lang.NoSuchFieldException: field_226571_aq_
# [07:16:48 WARN]: 	at java.base/java.lang.Class.getDeclaredField(Class.java:2782)
# [07:16:48 WARN]: 	at net.minecraftforge.fml.common.ObfuscationReflectionHelper.findField(ObfuscationReflectionHelper.java:222)
# [07:16:48 WARN]: 	... 14 more
# [07:18:08 INFO]: CREATING AND INIT'ING CARVER W DIMENSION minecraft:overworld...
# [07:18:08 INFO]: Better Caves config file for dimension minecraft:overworld not found. Using global config...
# [07:18:08 INFO]: Using block 'minecraft:lava' as lava in cave generation for dimension minecraft:overworld
# [07:18:08 INFO]: Using block 'Block{minecraft:water}[level=0]' as water in cave generation for dimension minecraft:overworld
# [07:18:20 INFO]: Unknown zombie entity type duneons:frozenzombie for zombie target task
# [07:18:39 INFO]: Unknown zombie entity type duneons:zombievangruard for zombie target task
# >
